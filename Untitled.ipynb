# %% [markdown]
# ### モデルの構築
# ---

# %%
from src.modeling.model import PSPNet
from torchinfo import summary
import torch

# %%
 def load_weights(tag_size: int=21, n_classes: int=5, weight_path: str="model/pspnet50_30.pth") -> object:
        # 学習済重みが21クラス分類のため合わせて読み込む
        net = PSPNet(tag_size)
        state = torch.load(weight_path, map_location={"cuda:0": "cpu"})
        key = list(state.keys())
        weights = {}
        
        for i in range(len(key)):
            weights[list(net.state_dict().keys())[i]] = state[list(key)[i]]
        state = net.state_dict()
        state.update(weights)
        net.load_state_dict(state)
        # 最終層のみ学習させる
        if tag_size != n_classes:
            net.decoder.classification = nn.Conv2d(512, n_classes, 3, 1, 1, 0)
            net.aux.classification = nn.Conv2d(256, n_classes, 3, 1, 1, 0)
            net.decoder.classification.apply(weights_init)
            net.aux.classification.apply(weights_init)
            
            lr_weights = ["decoder.classification.weights", "decoder.classification.bias", 
                         "aux.classification.weights", "aux.classification.bias"]
            for name, weight in net.named_parameters():
                if neme in lr_weights:
                    weight.requires_grad = True 
                else:
                    weight.requires_grad = False
        return net 
    
net = load_weights()

# %%
net
# Out:
# PSPNet(
#   (feature): FeatureMap_convolution(
#     (layer1): conv2normRelu(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (layer2): conv2normRelu(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (layer3): conv2normRelu(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (layer4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (res_1): ResidentBlockPSP(
# ...
